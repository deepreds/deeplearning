# %%
import numpy as np
import tensorflow as tf

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = '0' # Set to -1 if CPU should be used CPU = -1 , GPU = 0

gpus = tf.config.experimental.list_physical_devices('GPU')
cpus = tf.config.experimental.list_physical_devices('CPU')

if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
elif cpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        logical_cpus= tf.config.experimental.list_logical_devices('CPU')
        print(len(cpus), "Physical CPU,", len(logical_cpus), "Logical CPU")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
x_train = [1, 2, 3, 4]
y_train = [0, -1, -2, -3]

# %%
# %load_ext tensorboard

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from datetime import datetime
from packaging import version

# %%
model = tf.keras.Sequential()

# %%
# units == output shape, input_dim == input shape
model.add(tf.keras.layers.Dense(units=1, input_dim=1))

# %%
sgd = tf.keras.optimizers.SGD(lr=0.1)  # SGD == standard gradient descendent, lr == learning rate

# %%
model.compile(loss='mse', optimizer=sgd)  # mse == mean_squared_error, 1/m * sig (y'-y)^2

# %%
#from tensorflow.python.ops import summary_ops_v2
#from tensorflow.python.keras.backend import get_graph
##tb_path = "."
#tb_writer = tf.summary.create_file_writer(tb_path)
#with tb_writer.as_default():
#    if not tf.model.run_eagerly:
#        summary_ops_v2.graph(get_graph(), step=0)

# %%
# Define the Keras TensorBoard callback.
logdir="logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
# prints summary of the model to the terminal
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit() executes training
#from tqdm.keras import TqdmCallback
#tf.model.fit(x_train, y_train, epochs=200, verbose=0, callbacks=[TqdmCallback(verbose=0)])
history = model.fit(x_train, y_train, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 0s 2ms/step - loss: 3.6390
# Epoch 2/200
# 1/1 [==============================] - 0s 994us/step - loss: 1.6852
# Epoch 3/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.8050
# Epoch 4/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4069
# Epoch 5/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2255
# Epoch 6/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1415
# Epoch 7/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1014
# Epoch 8/200
# 1/1 [==============================] - 0s 1000us/step - loss: 0.0812
# Epoch 9/200
# 1/1 [==============================] - 0s 999us/step - loss: 0.0700
# Epoch 10/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0630
# Epoch 11/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0580
# Epoch 12/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0540
# Epoch 13/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0506
# Epoch 14/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0475
# Epoch 15/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0446
# Epoch 16/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0420
# Epoch 17/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0395
# Epoch 18/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0371
# Epoch 19/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0349
# Epoch 20/200
# 1/1 [==============================] - 0s 998us/step - loss: 0.0329
# Epoch 21/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0309
# Epoch 22/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0291
# Epoch 23/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0274
# Epoch 24/200
# 1/1 [==============================] - 0s 999us/step - loss: 0.0258
# Epoch 25/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0243
# Epoch 26/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0228
# Epoch 27/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0215
# Epoch 28/200
# 1/1 [==============================] - 0s 998us/step - loss: 0.0202
# Epoch 29/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0190
# Epoch 30/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0179
# Epoch 31/200
# 1/1 [==============================] - 0s 1000us/step - loss: 0.0168
# Epoch 32/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0159
# Epoch 33/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0149
# Epoch 34/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0140
# Epoch 35/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0132
# Epoch 36/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0124
# Epoch 37/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0117
# Epoch 38/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0110
# Epoch 39/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0104
# Epoch 40/200
# 1/1 [==============================] - 0s 999us/step - loss: 0.0097
# Epoch 41/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0092
# Epoch 42/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0086
# Epoch 43/200
# 1/1 [==============================] - 0s 999us/step - loss: 0.0081
# Epoch 44/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 45/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0072
# Epoch 46/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0068
# Epoch 47/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0064
# Epoch 48/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 49/200
# 1/1 [==============================] - ETA: 0s - loss: 0.005 - 0s 999us/step - loss: 0.0056
# Epoch 50/200
# 1/1 [==============================] - 0s 995us/step - loss: 0.0053
# Epoch 51/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0050
# Epoch 52/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0047
# Epoch 53/200
# 1/1 [==============================] - 0s 998us/step - loss: 0.0044
# Epoch 54/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 55/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 56/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0037
# Epoch 57/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0035
# Epoch 58/200
# 1/1 [==============================] - 0s 998us/step - loss: 0.0033
# Epoch 59/200
# 1/1 [==============================] - 0s 999us/step - loss: 0.0031
# Epoch 60/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 61/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 62/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 63/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 64/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0023
# Epoch 65/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0021
# Epoch 66/200
# 1/1 [==============================] - 0s 999us/step - loss: 0.0020
# Epoch 67/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0019
# Epoch 68/200
# 1/1 [==============================] - 0s 998us/step - loss: 0.0018
# Epoch 69/200
# 1/1 [==============================] - 0s 999us/step - loss: 0.0017
# Epoch 70/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0016
# Epoch 71/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 72/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 73/200
# 1/1 [==============================] - 0s 999us/step - loss: 0.0013
# Epoch 74/200
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0012
# Epoch 75/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 76/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 77/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 78/200
# 1/1 [==============================] - 0s 1ms/step - loss: 9.6739e-04
# Epoch 79/200
# 1/1 [==============================] - 0s 2ms/step - loss: 9.1033e-04
# Epoch 80/200
# 1/1 [==============================] - 0s 1ms/step - loss: 8.5664e-04
# Epoch 81/200
# 1/1 [==============================] - 0s 999us/step - loss: 8.0611e-04
# Epoch 82/200
# 1/1 [==============================] - 0s 999us/step - loss: 7.5857e-04
# Epoch 83/200
# 1/1 [==============================] - 0s 2ms/step - loss: 7.1382e-04
# Epoch 84/200
# 1/1 [==============================] - 0s 2ms/step - loss: 6.7172e-04
# Epoch 85/200
# 1/1 [==============================] - 0s 2ms/step - loss: 6.3210e-04
# Epoch 86/200
# 1/1 [==============================] - 0s 2ms/step - loss: 5.9482e-04
# Epoch 87/200
# 1/1 [==============================] - 0s 2ms/step - loss: 5.5974e-04
# Epoch 88/200
# 1/1 [==============================] - 0s 999us/step - loss: 5.2672e-04
# Epoch 89/200
# 1/1 [==============================] - 0s 1ms/step - loss: 4.9566e-04
# Epoch 90/200
# 1/1 [==============================] - 0s 1000us/step - loss: 4.6642e-04
# Epoch 91/200
# 1/1 [==============================] - 0s 2ms/step - loss: 4.3891e-04
# Epoch 92/200
# 1/1 [==============================] - 0s 1ms/step - loss: 4.1302e-04
# Epoch 93/200
# 1/1 [==============================] - 0s 2ms/step - loss: 3.8866e-04
# Epoch 94/200
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6574e-04
# Epoch 95/200
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4417e-04
# Epoch 96/200
# 1/1 [==============================] - 0s 2ms/step - loss: 3.2386e-04
# Epoch 97/200
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0476e-04
# Epoch 98/200
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8679e-04
# Epoch 99/200
# 1/1 [==============================] - 0s 998us/step - loss: 2.6987e-04
# Epoch 100/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.5395e-04
# Epoch 101/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3898e-04
# Epoch 102/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2488e-04
# Epoch 103/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1162e-04
# Epoch 104/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9913e-04
# Epoch 105/200
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8739e-04
# Epoch 106/200
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7634e-04
# Epoch 107/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6594e-04
# Epoch 108/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5615e-04
# Epoch 109/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4694e-04
# Epoch 110/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3827e-04
# Epoch 111/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3012e-04
# Epoch 112/200
# 1/1 [==============================] - 0s 1000us/step - loss: 1.2244e-04
# Epoch 113/200
# 1/1 [==============================] - 0s 998us/step - loss: 1.1522e-04
# Epoch 114/200
# 1/1 [==============================] - 0s 1000us/step - loss: 1.0842e-04
# Epoch 115/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0203e-04
# Epoch 116/200
# 1/1 [==============================] - 0s 1ms/step - loss: 9.6012e-05
# Epoch 117/200
# 1/1 [==============================] - 0s 2ms/step - loss: 9.0349e-05
# Epoch 118/200
# 1/1 [==============================] - 0s 2ms/step - loss: 8.5019e-05
# Epoch 119/200
# 1/1 [==============================] - 0s 2ms/step - loss: 8.0005e-05
# Epoch 120/200
# 1/1 [==============================] - 0s 2ms/step - loss: 7.5286e-05
# Epoch 121/200
# 1/1 [==============================] - 0s 2ms/step - loss: 7.0845e-05
# Epoch 122/200
# 1/1 [==============================] - 0s 2ms/step - loss: 6.6667e-05
# Epoch 123/200
# 1/1 [==============================] - 0s 2ms/step - loss: 6.2734e-05
# Epoch 124/200
# 1/1 [==============================] - 0s 2ms/step - loss: 5.9035e-05
# Epoch 125/200
# 1/1 [==============================] - 0s 2ms/step - loss: 5.5552e-05
# Epoch 126/200
# 1/1 [==============================] - 0s 1000us/step - loss: 5.2275e-05
# Epoch 127/200
# 1/1 [==============================] - 0s 2ms/step - loss: 4.9192e-05
# Epoch 128/200
# 1/1 [==============================] - 0s 2ms/step - loss: 4.6290e-05
# Epoch 129/200
# 1/1 [==============================] - 0s 2ms/step - loss: 4.3561e-05
# Epoch 130/200
# 1/1 [==============================] - 0s 2ms/step - loss: 4.0991e-05
# Epoch 131/200
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8573e-05
# Epoch 132/200
# 1/1 [==============================] - 0s 2ms/step - loss: 3.6299e-05
# Epoch 133/200
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4157e-05
# Epoch 134/200
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2143e-05
# Epoch 135/200
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0247e-05
# Epoch 136/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.8463e-05
# Epoch 137/200
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6784e-05
# Epoch 138/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.5204e-05
# Epoch 139/200
# 1/1 [==============================] - 0s 1000us/step - loss: 2.3717e-05
# Epoch 140/200
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2319e-05
# Epoch 141/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1002e-05
# Epoch 142/200
# 1/1 [==============================] - 0s 998us/step - loss: 1.9763e-05
# Epoch 143/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8598e-05
# Epoch 144/200
# 1/1 [==============================] - 0s 998us/step - loss: 1.7501e-05
# Epoch 145/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6469e-05
# Epoch 146/200
# 1/1 [==============================] - ETA: 0s - loss: 1.5497e-0 - 0s 999us/step - loss: 1.5497e-05
# Epoch 147/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4583e-05
# Epoch 148/200
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3723e-05
# Epoch 149/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2914e-05
# Epoch 150/200
# 1/1 [==============================] - 0s 998us/step - loss: 1.2152e-05
# Epoch 151/200
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1435e-05
# Epoch 152/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0761e-05
# Epoch 153/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0126e-05
# Epoch 154/200
# 1/1 [==============================] - 0s 2ms/step - loss: 9.5290e-06
# Epoch 155/200
# 1/1 [==============================] - 0s 999us/step - loss: 8.9668e-06
# Epoch 156/200
# 1/1 [==============================] - 0s 1ms/step - loss: 8.4378e-06
# Epoch 157/200
# 1/1 [==============================] - 0s 994us/step - loss: 7.9403e-06
# Epoch 158/200
# 1/1 [==============================] - 0s 2ms/step - loss: 7.4718e-06
# Epoch 159/200
# 1/1 [==============================] - 0s 1ms/step - loss: 7.0313e-06
# Epoch 160/200
# 1/1 [==============================] - 0s 1ms/step - loss: 6.6165e-06
# Epoch 161/200
# 1/1 [==============================] - 0s 2ms/step - loss: 6.2262e-06
# Epoch 162/200
# 1/1 [==============================] - 0s 2ms/step - loss: 5.8591e-06
# Epoch 163/200
# 1/1 [==============================] - 0s 999us/step - loss: 5.5134e-06
# Epoch 164/200
# 1/1 [==============================] - 0s 2ms/step - loss: 5.1883e-06
# Epoch 165/200
# 1/1 [==============================] - 0s 2ms/step - loss: 4.8821e-06
# Epoch 166/200
# 1/1 [==============================] - 0s 2ms/step - loss: 4.5942e-06
# Epoch 167/200
# 1/1 [==============================] - 0s 1ms/step - loss: 4.3233e-06
# Epoch 168/200
# 1/1 [==============================] - 0s 2ms/step - loss: 4.0685e-06
# Epoch 169/200
# 1/1 [==============================] - 0s 2ms/step - loss: 3.8285e-06
# Epoch 170/200
# 1/1 [==============================] - 0s 2ms/step - loss: 3.6026e-06
# Epoch 171/200
# 1/1 [==============================] - 0s 2ms/step - loss: 3.3901e-06
# Epoch 172/200
# 1/1 [==============================] - 0s 2ms/step - loss: 3.1902e-06
# Epoch 173/200
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0020e-06
# Epoch 174/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.8249e-06
# Epoch 175/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6582e-06
# Epoch 176/200
# 1/1 [==============================] - 0s 999us/step - loss: 2.5014e-06
# Epoch 177/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3539e-06
# Epoch 178/200
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2151e-06
# Epoch 179/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0844e-06
# Epoch 180/200
# 1/1 [==============================] - 0s 998us/step - loss: 1.9615e-06
# Epoch 181/200
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8458e-06
# Epoch 182/200
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7370e-06
# Epoch 183/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6345e-06
# Epoch 184/200
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5381e-06
# Epoch 185/200
# 1/1 [==============================] - 0s 999us/step - loss: 1.4473e-06
# Epoch 186/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3620e-06
# Epoch 187/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2816e-06
# Epoch 188/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2060e-06
# Epoch 189/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1349e-06
# Epoch 190/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0680e-06
# Epoch 191/200
# 1/1 [==============================] - 0s 999us/step - loss: 1.0049e-06
# Epoch 192/200
# 1/1 [==============================] - 0s 998us/step - loss: 9.4561e-07
# Epoch 193/200
# 1/1 [==============================] - 0s 2ms/step - loss: 8.8989e-07
# Epoch 194/200
# 1/1 [==============================] - 0s 998us/step - loss: 8.3739e-07
# Epoch 195/200
# 1/1 [==============================] - 0s 1ms/step - loss: 7.8797e-07
# Epoch 196/200
# 1/1 [==============================] - 0s 2ms/step - loss: 7.4154e-07
# Epoch 197/200
# 1/1 [==============================] - 0s 2ms/step - loss: 6.9778e-07
# Epoch 198/200
# 1/1 [==============================] - 0s 999us/step - loss: 6.5661e-07
# Epoch 199/200
# 1/1 [==============================] - 0s 2ms/step - loss: 6.1792e-07
# Epoch 200/200
# 1/1 [==============================] - 0s 1ms/step - loss: 5.8149e-07

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(history.history['loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# open http://localhost:6006/ in another tab
# %tensorboard --logdir logs
# Out:
# ERROR: Timed out waiting for TensorBoard to start. It may still be running as pid 31556.

# %%
# predict() returns predicted value
y_predict = model.predict(np.array([5, 4]))

# %%
print(y_predict)
# Out:
# [[-3.998732 ]
#  [-2.9993477]]
