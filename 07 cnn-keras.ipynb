# %%
#https://www.pyimagesearch.com/2018/04/16/keras-and-convolutional-neural-networks-cnns/
import tensorflow as tf

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = '-1' # Set to -1 if CPU should be used CPU = -1 , GPU = 0

gpus = tf.config.experimental.list_physical_devices('GPU')
cpus = tf.config.experimental.list_physical_devices('CPU')

if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
elif cpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        logical_cpus= tf.config.experimental.list_logical_devices('CPU')
        print(len(cpus), "Physical CPU,", len(logical_cpus), "Logical CPU")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical CPU, 1 Logical CPU

# %%
# import the necessary packages
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras import backend as K
# import the necessary packages
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from imutils import paths
import numpy as np
import random
import pickle
import cv2
# import the necessary packages
from keras.preprocessing.image import img_to_array
from keras.models import load_model
import imutils
import os
# Out:
# Using TensorFlow backend.

# %%
class SmallerVGGNet:
	@staticmethod
	def build(width, height, depth, classes):
		# initialize the model along with the input shape to be
		# "channels last" and the channels dimension itself
		model = Sequential()
		inputShape = (height, width, depth)
		chanDim = -1

		# if we are using "channels first", update the input shape
		# and channels dimension
		if K.image_data_format() == "channels_first":
			inputShape = (depth, height, width)
			chanDim = 1

		# CONV => RELU => POOL
		model.add(Conv2D(32, (3, 3), padding="same",
			input_shape=inputShape))
		model.add(Activation("relu"))
		model.add(BatchNormalization(axis=chanDim))
		model.add(MaxPooling2D(pool_size=(3, 3)))
		model.add(Dropout(0.25))

		# (CONV => RELU) * 2 => POOL
		model.add(Conv2D(64, (3, 3), padding="same"))
		model.add(Activation("relu"))
		model.add(BatchNormalization(axis=chanDim))
		model.add(Conv2D(64, (3, 3), padding="same"))
		model.add(Activation("relu"))
		model.add(BatchNormalization(axis=chanDim))
		model.add(MaxPooling2D(pool_size=(2, 2)))
		model.add(Dropout(0.25))

		# (CONV => RELU) * 2 => POOL
		model.add(Conv2D(128, (3, 3), padding="same"))
		model.add(Activation("relu"))
		model.add(BatchNormalization(axis=chanDim))
		model.add(Conv2D(128, (3, 3), padding="same"))
		model.add(Activation("relu"))
		model.add(BatchNormalization(axis=chanDim))
		model.add(MaxPooling2D(pool_size=(2, 2)))
		model.add(Dropout(0.25))

		# first (and only) set of FC => RELU layers
		model.add(Flatten())
		model.add(Dense(1024))
		model.add(Activation("relu"))
		model.add(BatchNormalization())
		model.add(Dropout(0.5))

		# softmax classifier
		model.add(Dense(classes))
		model.add(Activation("softmax"))

		# return the constructed network architecture
		return model

# %%
# initialize the number of epochs to train for, initial learning rate,
# batch size, and image dimensions
EPOCHS = 100
INIT_LR = 1e-3
BS = 32
IMAGE_DIMS = (96, 96, 3)

# %%
# grab the image paths and randomly shuffle them
print("[INFO] loading images...")
import zipfile
#imagePaths = sorted(list(paths.list_images('Pokemon')))
imagefilename = 'Pokemon.zip'
zf = zipfile.ZipFile(imagefilename)
random.seed(42)
imagePaths = zf.namelist()
random.seed(42)
random.shuffle(imagePaths)
# Out:
# [INFO] loading images...

# %%
# initialize the data and labels
data = []
labels = []
from tensorflow.keras.applications import imagenet_utils
# loop over the input images
for imagePath in imagePaths:
	# load the image, pre-process it, and store it in the data list
	#image = cv2.imread(imagePath)
	image = cv2.imdecode(np.frombuffer(zf.read(imagePath), np.uint8), 1)
	image = cv2.resize(image, (IMAGE_DIMS[1], IMAGE_DIMS[0]))
	#image = img_to_array(image)
	#image = np.expand_dims(image, axis=0)
	image = imagenet_utils.preprocess_input(image)
	data.append(image)
 
	# extract the class label from the image path and update the
	# labels list
	#label = imagePath.split(os.path.sep)[-2]
	label = imagePath.split('/', 1)[0]
	labels.append(label)

# %%
# scale the raw pixel intensities to the range [0, 1]
data = np.array(data, dtype="float") / 255.0
labels = np.array(labels)
print("[INFO] data matrix: {:.2f}MB".format(data.nbytes / (1024 * 1000.0)))
# Out:
# [INFO] data matrix: 252.29MB

# %%
print(data.shape)
print(labels.shape)
# Out:
# (1168, 96, 96, 3)
# (1168,)

# %%
# binarize the labels
lb = LabelBinarizer()
labels = lb.fit_transform(labels)

# %%
# partition the data into training and testing splits using 80% of
# the data for training and the remaining 20% for testing
(trainX, testX, trainY, testY) = train_test_split(data,labels, test_size=0.2, random_state=42)

# %%
# construct the image generator for data augmentation
aug = ImageDataGenerator(rotation_range=25, width_shift_range=0.1,height_shift_range=0.1, shear_range=0.2, zoom_range=0.2,horizontal_flip=True, fill_mode="nearest")

# %%
# initialize the model
print("[INFO] compiling model...")
model = SmallerVGGNet.build(width=IMAGE_DIMS[1], height=IMAGE_DIMS[0],depth=IMAGE_DIMS[2], classes=len(lb.classes_))
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)
model.compile(loss="categorical_crossentropy", optimizer=opt,metrics=["accuracy"])
# Out:
# [INFO] compiling model...

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 96, 96, 32)        896
# _________________________________________________________________
# activation_1 (Activation)    (None, 96, 96, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 96, 96, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# activation_4 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# activation_5 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              8389632
# _________________________________________________________________
# activation_6 (Activation)    (None, 1024)              0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 5125
# _________________________________________________________________
# activation_7 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 8,678,277
# Trainable params: 8,675,397
# Non-trainable params: 2,880
# _________________________________________________________________

# %%
# train the network
print("[INFO] training network...")
H = model.fit_generator(aug.flow(trainX, trainY, batch_size=BS),validation_data=(testX, testY),steps_per_epoch=len(trainX) // BS,epochs=EPOCHS, verbose=1)
# Out:
# [INFO] training network...
# Epoch 1/100
# 29/29 [==============================] - 34s 1s/step - loss: 1.3438 - accuracy: 0.6308 - val_loss: 2.2690 - val_accuracy: 0.2735
# Epoch 2/100
# 29/29 [==============================] - 31s 1s/step - loss: 0.7200 - accuracy: 0.7639 - val_loss: 2.2492 - val_accuracy: 0.3462
# Epoch 3/100
# 29/29 [==============================] - 30s 1s/step - loss: 0.5962 - accuracy: 0.8215 - val_loss: 3.0991 - val_accuracy: 0.3077
# Epoch 4/100
# 29/29 [==============================] - 32s 1s/step - loss: 0.7529 - accuracy: 0.8137 - val_loss: 3.8343 - val_accuracy: 0.2436
# Epoch 5/100
# 29/29 [==============================] - 30s 1s/step - loss: 0.6023 - accuracy: 0.8259 - val_loss: 5.8725 - val_accuracy: 0.1880
# Epoch 6/100
# 29/29 [==============================] - 31s 1s/step - loss: 0.4973 - accuracy: 0.8621 - val_loss: 3.3370 - val_accuracy: 0.3120
# Epoch 7/100
# 29/29 [==============================] - 30s 1s/step - loss: 0.5153 - accuracy: 0.8326 - val_loss: 3.3427 - val_accuracy: 0.3761
# Epoch 8/100
# 29/29 [==============================] - 32s 1s/step - loss: 0.3827 - accuracy: 0.8758 - val_loss: 1.9417 - val_accuracy: 0.5043
# Epoch 9/100
# 29/29 [==============================] - 30s 1s/step - loss: 0.3843 - accuracy: 0.8790 - val_loss: 2.4768 - val_accuracy: 0.3974
# Epoch 10/100
# 29/29 [==============================] - 31s 1s/step - loss: 0.3690 - accuracy: 0.8780 - val_loss: 2.4142 - val_accuracy: 0.3632
# Epoch 11/100
# 29/29 [==============================] - 33s 1s/step - loss: 0.3934 - accuracy: 0.8728 - val_loss: 2.0593 - val_accuracy: 0.4231
# Epoch 12/100
# 29/29 [==============================] - 33s 1s/step - loss: 0.4749 - accuracy: 0.8710 - val_loss: 1.5920 - val_accuracy: 0.5598
# Epoch 13/100
# 29/29 [==============================] - 31s 1s/step - loss: 0.3542 - accuracy: 0.8890 - val_loss: 1.5210 - val_accuracy: 0.5769
# Epoch 14/100
# 29/29 [==============================] - 33s 1s/step - loss: 0.4249 - accuracy: 0.8747 - val_loss: 1.3907 - val_accuracy: 0.6111
# Epoch 15/100
# 29/29 [==============================] - 29s 1s/step - loss: 0.3525 - accuracy: 0.8925 - val_loss: 1.0888 - val_accuracy: 0.7009
# Epoch 16/100
# 29/29 [==============================] - 30s 1s/step - loss: 0.4551 - accuracy: 0.8642 - val_loss: 0.9475 - val_accuracy: 0.7436
# Epoch 17/100
# 29/29 [==============================] - 33s 1s/step - loss: 0.4301 - accuracy: 0.8647 - val_loss: 1.0051 - val_accuracy: 0.7350
# Epoch 18/100
# 29/29 [==============================] - 31s 1s/step - loss: 0.3607 - accuracy: 0.8991 - val_loss: 0.7489 - val_accuracy: 0.7650
# Epoch 19/100
# 29/29 [==============================] - 32s 1s/step - loss: 0.2919 - accuracy: 0.9030 - val_loss: 0.3505 - val_accuracy: 0.8761
# Epoch 20/100
# 29/29 [==============================] - 32s 1s/step - loss: 0.3189 - accuracy: 0.8980 - val_loss: 0.3942 - val_accuracy: 0.8932
# Epoch 21/100
# 29/29 [==============================] - 29s 1s/step - loss: 0.3379 - accuracy: 0.8836 - val_loss: 0.3892 - val_accuracy: 0.8718
# Epoch 22/100
# 29/29 [==============================] - 28s 975ms/step - loss: 0.2872 - accuracy: 0.9013 - val_loss: 0.2792 - val_accuracy: 0.9103
# Epoch 23/100
# 29/29 [==============================] - 28s 967ms/step - loss: 0.2850 - accuracy: 0.9002 - val_loss: 0.3920 - val_accuracy: 0.8846
# Epoch 24/100
# 29/29 [==============================] - 27s 930ms/step - loss: 0.2332 - accuracy: 0.9212 - val_loss: 0.5249 - val_accuracy: 0.8590
# Epoch 25/100
# 29/29 [==============================] - 29s 1s/step - loss: 0.2694 - accuracy: 0.9116 - val_loss: 0.3089 - val_accuracy: 0.9103
# Epoch 26/100
# 29/29 [==============================] - 29s 984ms/step - loss: 0.3200 - accuracy: 0.9146 - val_loss: 0.4588 - val_accuracy: 0.8462
# Epoch 27/100
# 29/29 [==============================] - 28s 954ms/step - loss: 0.2587 - accuracy: 0.9146 - val_loss: 0.2959 - val_accuracy: 0.9145
# Epoch 28/100
# 29/29 [==============================] - 29s 988ms/step - loss: 0.2335 - accuracy: 0.9246 - val_loss: 0.2272 - val_accuracy: 0.9188
# Epoch 29/100
# 29/29 [==============================] - 30s 1s/step - loss: 0.1978 - accuracy: 0.9357 - val_loss: 0.4533 - val_accuracy: 0.8632
# Epoch 30/100
# 29/29 [==============================] - 30s 1s/step - loss: 0.2542 - accuracy: 0.9213 - val_loss: 0.3643 - val_accuracy: 0.9017
# Epoch 31/100
# 29/29 [==============================] - 35s 1s/step - loss: 0.1838 - accuracy: 0.9379 - val_loss: 0.3488 - val_accuracy: 0.9103
# Epoch 32/100
# 29/29 [==============================] - 33s 1s/step - loss: 0.2380 - accuracy: 0.9268 - val_loss: 0.4407 - val_accuracy: 0.8803
# Epoch 33/100
# 29/29 [==============================] - 34s 1s/step - loss: 0.3213 - accuracy: 0.9202 - val_loss: 0.3649 - val_accuracy: 0.8932
# Epoch 34/100
# 29/29 [==============================] - 33s 1s/step - loss: 0.2216 - accuracy: 0.9368 - val_loss: 0.3446 - val_accuracy: 0.8974
# Epoch 35/100
# 29/29 [==============================] - 32s 1s/step - loss: 0.2439 - accuracy: 0.9289 - val_loss: 0.3955 - val_accuracy: 0.8846
# Epoch 36/100
# 29/29 [==============================] - 32s 1s/step - loss: 0.1707 - accuracy: 0.9412 - val_loss: 0.4039 - val_accuracy: 0.9017
# Epoch 37/100
# 29/29 [==============================] - 35s 1s/step - loss: 0.2272 - accuracy: 0.9338 - val_loss: 0.4318 - val_accuracy: 0.8932
# Epoch 38/100
# 29/29 [==============================] - 31s 1s/step - loss: 0.3197 - accuracy: 0.9157 - val_loss: 0.3335 - val_accuracy: 0.9017
# Epoch 39/100
# 29/29 [==============================] - 32s 1s/step - loss: 0.1452 - accuracy: 0.9483 - val_loss: 0.2691 - val_accuracy: 0.9231
# Epoch 40/100
# 29/29 [==============================] - 30s 1s/step - loss: 0.1927 - accuracy: 0.9441 - val_loss: 0.4918 - val_accuracy: 0.8761
# Epoch 41/100
# 29/29 [==============================] - 34s 1s/step - loss: 0.2250 - accuracy: 0.9290 - val_loss: 0.3956 - val_accuracy: 0.9145
# Epoch 42/100
# 29/29 [==============================] - 34s 1s/step - loss: 0.1483 - accuracy: 0.9397 - val_loss: 0.4651 - val_accuracy: 0.9017
# Epoch 43/100
# 29/29 [==============================] - 32s 1s/step - loss: 0.2318 - accuracy: 0.9247 - val_loss: 0.3547 - val_accuracy: 0.9017
# Epoch 44/100
# 29/29 [==============================] - 33s 1s/step - loss: 0.1842 - accuracy: 0.9401 - val_loss: 0.3355 - val_accuracy: 0.9231
# Epoch 45/100
# 29/29 [==============================] - 32s 1s/step - loss: 0.2272 - accuracy: 0.9278 - val_loss: 0.4008 - val_accuracy: 0.8974
# Epoch 46/100
# 29/29 [==============================] - 31s 1s/step - loss: 0.1963 - accuracy: 0.9406 - val_loss: 0.6751 - val_accuracy: 0.8803
# Epoch 47/100
# 29/29 [==============================] - 31s 1s/step - loss: 0.1747 - accuracy: 0.9379 - val_loss: 0.4293 - val_accuracy: 0.9359
# Epoch 48/100
# 29/29 [==============================] - 32s 1s/step - loss: 0.1607 - accuracy: 0.9401 - val_loss: 0.4098 - val_accuracy: 0.9017
# Epoch 49/100
# 29/29 [==============================] - 31s 1s/step - loss: 0.1658 - accuracy: 0.9397 - val_loss: 0.3755 - val_accuracy: 0.9188
# Epoch 50/100
# 29/29 [==============================] - 31s 1s/step - loss: 0.1479 - accuracy: 0.9566 - val_loss: 0.3470 - val_accuracy: 0.9017
# Epoch 51/100
# 29/29 [==============================] - 36s 1s/step - loss: 0.1595 - accuracy: 0.9483 - val_loss: 0.3167 - val_accuracy: 0.9231
# Epoch 52/100
# 29/29 [==============================] - 35s 1s/step - loss: 0.2642 - accuracy: 0.9357 - val_loss: 0.4470 - val_accuracy: 0.8974
# Epoch 53/100
# 29/29 [==============================] - 33s 1s/step - loss: 0.1964 - accuracy: 0.9324 - val_loss: 0.4406 - val_accuracy: 0.8761
# Epoch 54/100
# 29/29 [==============================] - 31s 1s/step - loss: 0.1821 - accuracy: 0.9406 - val_loss: 0.5078 - val_accuracy: 0.8889
# Epoch 55/100
# 29/29 [==============================] - 34s 1s/step - loss: 0.1470 - accuracy: 0.9601 - val_loss: 0.5016 - val_accuracy: 0.8590
# Epoch 56/100
# 29/29 [==============================] - 36s 1s/step - loss: 0.1237 - accuracy: 0.9568 - val_loss: 0.4101 - val_accuracy: 0.8889
# Epoch 57/100
# 29/29 [==============================] - 43s 1s/step - loss: 0.2488 - accuracy: 0.9335 - val_loss: 0.7692 - val_accuracy: 0.8504
# Epoch 58/100
# 29/29 [==============================] - 36s 1s/step - loss: 0.1587 - accuracy: 0.9512 - val_loss: 0.4949 - val_accuracy: 0.8932
# Epoch 59/100
# 29/29 [==============================] - 37s 1s/step - loss: 0.1765 - accuracy: 0.9501 - val_loss: 0.5017 - val_accuracy: 0.8718
# Epoch 60/100
# 29/29 [==============================] - 31s 1s/step - loss: 0.1951 - accuracy: 0.9302 - val_loss: 0.4707 - val_accuracy: 0.8974
# Epoch 61/100
# 29/29 [==============================] - 41s 1s/step - loss: 0.2041 - accuracy: 0.9401 - val_loss: 0.5084 - val_accuracy: 0.8846
# Epoch 62/100
# 29/29 [==============================] - 41s 1s/step - loss: 0.1423 - accuracy: 0.9568 - val_loss: 0.4177 - val_accuracy: 0.8803
# Epoch 63/100
# 29/29 [==============================] - 52s 2s/step - loss: 0.1765 - accuracy: 0.9512 - val_loss: 0.4371 - val_accuracy: 0.9103
# Epoch 64/100
# 29/29 [==============================] - 56s 2s/step - loss: 0.2386 - accuracy: 0.9335 - val_loss: 0.3831 - val_accuracy: 0.9145
# Epoch 65/100
# 29/29 [==============================] - 54s 2s/step - loss: 0.1829 - accuracy: 0.9412 - val_loss: 0.3736 - val_accuracy: 0.8889
# Epoch 66/100
# 29/29 [==============================] - 49s 2s/step - loss: 0.1980 - accuracy: 0.9368 - val_loss: 0.4061 - val_accuracy: 0.8974
# Epoch 67/100
# 29/29 [==============================] - 48s 2s/step - loss: 0.2316 - accuracy: 0.9390 - val_loss: 0.4619 - val_accuracy: 0.8547
# Epoch 68/100
# 29/29 [==============================] - 55s 2s/step - loss: 0.1600 - accuracy: 0.9534 - val_loss: 0.7502 - val_accuracy: 0.8590
# Epoch 69/100
# 29/29 [==============================] - 53s 2s/step - loss: 0.1314 - accuracy: 0.9501 - val_loss: 0.4362 - val_accuracy: 0.9188
# Epoch 70/100
# 29/29 [==============================] - 62s 2s/step - loss: 0.1321 - accuracy: 0.9644 - val_loss: 0.3137 - val_accuracy: 0.9274
# Epoch 71/100
# 29/29 [==============================] - 55s 2s/step - loss: 0.1599 - accuracy: 0.9578 - val_loss: 0.2918 - val_accuracy: 0.9316
# Epoch 72/100
# 29/29 [==============================] - 52s 2s/step - loss: 0.1340 - accuracy: 0.9569 - val_loss: 0.2604 - val_accuracy: 0.9402
# Epoch 73/100
# 29/29 [==============================] - 53s 2s/step - loss: 0.1192 - accuracy: 0.9568 - val_loss: 0.2430 - val_accuracy: 0.9402
# Epoch 74/100
# 29/29 [==============================] - 56s 2s/step - loss: 0.0811 - accuracy: 0.9690 - val_loss: 0.2705 - val_accuracy: 0.9316
# Epoch 75/100
# 29/29 [==============================] - 55s 2s/step - loss: 0.1678 - accuracy: 0.9490 - val_loss: 0.2762 - val_accuracy: 0.9188
# Epoch 76/100
# 29/29 [==============================] - 53s 2s/step - loss: 0.2011 - accuracy: 0.9512 - val_loss: 0.4154 - val_accuracy: 0.9145
# Epoch 77/100
# 29/29 [==============================] - 50s 2s/step - loss: 0.2314 - accuracy: 0.9463 - val_loss: 0.8418 - val_accuracy: 0.8547
# Epoch 78/100
# 29/29 [==============================] - 42s 1s/step - loss: 0.1401 - accuracy: 0.9545 - val_loss: 0.4280 - val_accuracy: 0.9060
# Epoch 79/100
# 29/29 [==============================] - 39s 1s/step - loss: 0.1387 - accuracy: 0.9483 - val_loss: 0.3104 - val_accuracy: 0.9017
# Epoch 80/100
# 29/29 [==============================] - 36s 1s/step - loss: 0.1836 - accuracy: 0.9509 - val_loss: 0.4751 - val_accuracy: 0.8932
# Epoch 81/100
# 29/29 [==============================] - 36s 1s/step - loss: 0.1206 - accuracy: 0.9526 - val_loss: 0.3935 - val_accuracy: 0.9145
# Epoch 82/100
# 29/29 [==============================] - 37s 1s/step - loss: 0.2283 - accuracy: 0.9390 - val_loss: 0.7588 - val_accuracy: 0.8504
# Epoch 83/100
# 29/29 [==============================] - 38s 1s/step - loss: 0.1446 - accuracy: 0.9545 - val_loss: 0.4571 - val_accuracy: 0.9145
# Epoch 84/100
# 29/29 [==============================] - 37s 1s/step - loss: 0.1157 - accuracy: 0.9656 - val_loss: 0.4461 - val_accuracy: 0.9017
# Epoch 85/100
# 29/29 [==============================] - 39s 1s/step - loss: 0.1134 - accuracy: 0.9501 - val_loss: 0.4666 - val_accuracy: 0.9274
# Epoch 86/100
# 29/29 [==============================] - 36s 1s/step - loss: 0.1387 - accuracy: 0.9566 - val_loss: 4.1015 - val_accuracy: 0.4744
# Epoch 87/100
# 29/29 [==============================] - 37s 1s/step - loss: 0.6254 - accuracy: 0.8233 - val_loss: 4.7564 - val_accuracy: 0.5214
# Epoch 88/100
# 29/29 [==============================] - 37s 1s/step - loss: 0.5435 - accuracy: 0.8659 - val_loss: 3.5467 - val_accuracy: 0.5513
# Epoch 89/100
# 29/29 [==============================] - 35s 1s/step - loss: 0.3240 - accuracy: 0.8869 - val_loss: 1.8811 - val_accuracy: 0.6538
# Epoch 90/100
# 29/29 [==============================] - 37s 1s/step - loss: 0.3380 - accuracy: 0.9024 - val_loss: 0.8346 - val_accuracy: 0.8248
# Epoch 91/100
# 29/29 [==============================] - 47s 2s/step - loss: 0.2285 - accuracy: 0.9235 - val_loss: 0.4341 - val_accuracy: 0.8718
# Epoch 92/100
# 29/29 [==============================] - 35s 1s/step - loss: 0.2553 - accuracy: 0.9157 - val_loss: 0.4871 - val_accuracy: 0.8761
# Epoch 93/100
# 29/29 [==============================] - 35s 1s/step - loss: 0.2285 - accuracy: 0.9290 - val_loss: 1.1855 - val_accuracy: 0.7607
# Epoch 94/100
# 29/29 [==============================] - 37s 1s/step - loss: 0.1807 - accuracy: 0.9407 - val_loss: 0.3487 - val_accuracy: 0.8932
# Epoch 95/100
# 29/29 [==============================] - 34s 1s/step - loss: 0.1987 - accuracy: 0.9338 - val_loss: 0.5862 - val_accuracy: 0.8504
# Epoch 96/100
# 29/29 [==============================] - 34s 1s/step - loss: 0.2014 - accuracy: 0.9343 - val_loss: 0.2898 - val_accuracy: 0.9274
# Epoch 97/100
# 29/29 [==============================] - 34s 1s/step - loss: 0.2151 - accuracy: 0.9258 - val_loss: 0.9862 - val_accuracy: 0.7906
# Epoch 98/100
# 29/29 [==============================] - 37s 1s/step - loss: 0.2228 - accuracy: 0.9302 - val_loss: 0.6525 - val_accuracy: 0.8504
# Epoch 99/100
# 29/29 [==============================] - 42s 1s/step - loss: 0.1742 - accuracy: 0.9390 - val_loss: 0.5648 - val_accuracy: 0.8504
# Epoch 100/100
# 29/29 [==============================] - 36s 1s/step - loss: 0.1670 - accuracy: 0.9472 - val_loss: 0.3710 - val_accuracy: 0.9103

# %%
import tempfile
TEMPDIR = tempfile.gettempdir()
# save the model to disk
print("[INFO] serializing network...")
model.save(os.path.join(TEMPDIR, 'cnn_keras.model'))
# Out:
# [INFO] serializing network...

# %%
# save the label binarizer to disk
print("[INFO] serializing label binarizer...")
f = open(os.path.join(TEMPDIR, 'cnn_keras_labelbin'), "wb")
f.write(pickle.dumps(lb))
f.close()
# Out:
# [INFO] serializing label binarizer...

# %%
# plot the training loss and accuracy
plt.figure()
N = EPOCHS
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="accuracy")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_accuracy")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="upper left")
plt.show()

# %%
# load the image
zf = zipfile.ZipFile('Pokemon_examples.zip')
#image = cv2.imread(os.path.join('Pokemon_examples', 'bulbasaur_plush.png'))
image = cv2.imdecode(np.frombuffer(zf.read('bulbasaur_plush.png'), np.uint8), 1)
output = image.copy()
exampleList = zf.namelist()

# %%
# pre-process the image for classification
image = cv2.resize(image, (96, 96))
image = image.astype("float") / 255.0
image = img_to_array(image)
image = np.expand_dims(image, axis=0)

# %%
# load the trained convolutional neural network and the label
# binarizer
print("[INFO] loading network...")
model = load_model(os.path.join(TEMPDIR, 'cnn_keras.model'))
lb = pickle.loads(open(os.path.join(TEMPDIR, 'cnn_keras_labelbin'), "rb").read())
# Out:
# [INFO] loading network...

# %%
# classify the input image
print("[INFO] classifying image...")
proba = model.predict(image)[0]
idx = np.argmax(proba)
label = lb.classes_[idx]
# Out:
# [INFO] classifying image...

# %%
print(exampleList)
print(label)
# Out:
# ['bulbasaur_plush.png', 'charmander_counter.png', 'charmander_hidden.png', 'mewtwo_toy.png', 'pikachu_toy.png', 'squirtle_plush.png']
# pikachu

# %%
# we'll mark our prediction as "correct" of the input image filename
# contains the predicted label text (obviously this makes the
# assumption that you have named your testing image files this way)
#filename = os.path.join('Pokemon_examples', 'bulbasaur_plush.png')[os.path.join('Pokemon_examples', 'bulbasaur_plush.png').rfind(os.path.sep) + 1:]
filename = exampleList[exampleList.index('bulbasaur_plush.png')]
correct = "correct" if filename.rfind(label) != -1 else "incorrect"

# %%
print(filename)
print(correct)
# Out:
# bulbasaur_plush.png
# incorrect

# %%
# build the label and draw the label on the image
label = "{}: {:.2f}% ({})".format(label, proba[idx] * 100, correct)
output = imutils.resize(output, width=400)
cv2.putText(output, label, (10, 25),  cv2.FONT_HERSHEY_SIMPLEX,0.7, (0, 255, 0), 2)
# Out:
# array([[[247, 249, 249],
#         [228, 230, 239],
#         [199, 201, 217],
#         ...,
#         [238, 234, 239],
#         [237, 234, 239],
#         [237, 235, 241]],
#
#        [[248, 249, 249],
#         [229, 231, 240],
#         [199, 202, 217],
#         ...,
#         [202, 193, 204],
#         [193, 185, 198],
#         [195, 190, 205]],
#
#        [[248, 250, 250],
#         [231, 233, 242],
#         [199, 202, 218],
#         ...,
#         [159, 149, 153],
#         [118, 106, 111],
#         [ 87,  78,  82]],
#
#        ...,
#
#        [[216, 218, 228],
#         [213, 215, 225],
#         [216, 218, 228],
#         ...,
#         [218, 222, 231],
#         [211, 216, 226],
#         [203, 208, 219]],
#
#        [[214, 216, 226],
#         [220, 222, 232],
#         [220, 222, 232],
#         ...,
#         [213, 216, 227],
#         [215, 219, 231],
#         [212, 216, 227]],
#
#        [[214, 216, 226],
#         [219, 221, 231],
#         [219, 221, 231],
#         ...,
#         [199, 206, 219],
#         [201, 208, 221],
#         [203, 211, 224]]], dtype=uint8)

# %%
# show the output image
print("[INFO] {}".format(label))
img = cv2.imread('img.jpg')
plt.imshow(output)
# Out:
# [INFO] pikachu: 50.45% (incorrect)
